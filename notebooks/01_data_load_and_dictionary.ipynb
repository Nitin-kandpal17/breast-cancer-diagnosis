# %% [markdown]
# # 🧠 Breast Cancer Diagnosis
# ## 📌 Task: Load UCI Breast Cancer Dataset + Create Data Dictionary
#
# **Objective:** Load the dataset, explore basic statistics, and generate an Excel-based data dictionary.
#
# **Dataset:** [Breast Cancer Wisconsin (Diagnostic)](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic))
# **Source:** sklearn.datasets (preprocessed version)
#
# ---

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Load dataset
data = load_breast_cancer()

# Create dataframe with features
df = pd.DataFrame(data.data, columns=data.feature_names)

# Add target
df["target"] = data.target

# Preview
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ### 🔍 Dataset Information
#
# - **Rows (samples):** 569
# - **Features:** 30
# - **Target values:** 0 (Malignant), 1 (Benign)
#
# The dataset describes characteristics of the cell nuclei present in digitized image of a breast mass.
#
# ---
#
# **Feature Groups:**
# - **Mean values**
# - **Standard Error**
# - **Worst (largest) values**
#
# For example:
# - `mean radius`, `mean texture`, `mean area` ...
# - `worst perimeter`, `worst concave points`, etc.
#
# ---

# %%
# Create data dictionary
desc = df.describe().T
desc["null_count"] = df.isnull().sum()
desc["data_type"] = df.dtypes

# Save as Excel
desc.to_excel("../outputs/data_dictionary.xlsx")

desc.head()
# Out:
#                  count        mean         std        min        25%  \
# mean radius      569.0   14.127292    3.524049    6.98100   11.70000
# mean texture     569.0   19.289649    4.301036    9.71000   16.17000
# mean perimeter   569.0   91.969033   24.298981   43.79000   75.17000
# mean area        569.0  654.889104  351.914129  143.50000  420.30000
# mean smoothness  569.0    0.096360    0.014064    0.05263    0.08637
#
#                        50%       75%        max  null_count data_type
# mean radius       13.37000   15.7800    28.1100           0   float64
# mean texture      18.84000   21.8000    39.2800           0   float64
# mean perimeter    86.24000  104.1000   188.5000           0   float64
# mean area        551.10000  782.7000  2501.0000           0   float64
# mean smoothness    0.09587    0.1053     0.1634           0   float64

# %% [markdown]
# ### ✅ Summary of Day 1
#
# - Successfully loaded the Breast Cancer dataset using `sklearn.datasets`.
# - Created a pandas DataFrame with 30 features + 1 target column.
# - Generated an Excel **data dictionary** with:
#   - Summary statistics
#   - Null value counts
#   - Data types
#
# ---
